# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train_df = pd.read_csv("C:/Users/Mariam/OneDrive/Desktop/Portfolio manenoz/House Prices Prediction/train.csv")
test_df = pd.read_csv("C:/Users/Mariam/OneDrive/Desktop/Portfolio manenoz/House Prices Prediction/test.csv")
sample_submission = pd.read_csv("C:/Users/Mariam/OneDrive/Desktop/Portfolio manenoz/House Prices Prediction/sample_submission.csv")

# %%
train_df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %% [markdown]
# The data has 81 Columns. The preview shows mixed datatypes and possible existence of null values. The `Id` column seems to be redundant and will be removed in the upcoming chapter

# %%
test_df.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence MiscFeature  \
# 0         Lvl    AllPub  ...         120        0    NaN  MnPrv         NaN
# 1         Lvl    AllPub  ...           0        0    NaN    NaN        Gar2
# 2         Lvl    AllPub  ...           0        0    NaN  MnPrv         NaN
# 3         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 4         HLS    AllPub  ...         144        0    NaN    NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition
# ...

# %% [markdown]
# The test dataset contains 80 columns. The only column excluded from this dataset is the response variable `SalePrice`. This is the column to be predicted.

# %%
sample_submission.head()
# Out:
#      Id      SalePrice
# 0  1461  169277.052498
# 1  1462  187758.393989
# 2  1463  183583.683570
# 3  1464  179317.477511
# 4  1465  150730.079977

# %% [markdown]
# The submission file sould contain two columns: The `ID`  column from the test data and the predicted `SalePrice`

# %%
print('The Train dataset has {train_rows} rows and {train_cols} columns'.format(train_rows=train_df.shape[0], train_cols=train_df.shape[1]))
print('The Test dataset has {test_rows} rows and {test_cols} columns'.format(test_rows=test_df.shape[0], test_cols=test_df.shape[1]))
# Out:
# The Train dataset has 1460 rows and 81 columns
# The Test dataset has 1459 rows and 80 columns

# %%
train_df.describe().T
# Out:
#                 count           mean           std      min        25%  \
# Id             1460.0     730.500000    421.610009      1.0     365.75
# MSSubClass     1460.0      56.897260     42.300571     20.0      20.00
# LotFrontage    1201.0      70.049958     24.284752     21.0      59.00
# LotArea        1460.0   10516.828082   9981.264932   1300.0    7553.50
# OverallQual    1460.0       6.099315      1.382997      1.0       5.00
# OverallCond    1460.0       5.575342      1.112799      1.0       5.00
# YearBuilt      1460.0    1971.267808     30.202904   1872.0    1954.00
# YearRemodAdd   1460.0    1984.865753     20.645407   1950.0    1967.00
# MasVnrArea     1452.0     103.685262    181.066207      0.0       0.00
# BsmtFinSF1     1460.0     443.639726    456.098091      0.0       0.00
# BsmtFinSF2     1460.0      46.549315    161.319273      0.0       0.00
# BsmtUnfSF      1460.0     567.240411    441.866955      0.0     223.00
# ...

# %% [markdown]
# There are very many columns, to be able to see the statistics of all of them, the Transpose method ha been used. Most of the numerical variables have no null values.

# %%
train_df.describe(include='O').T
# Out:
#               count unique      top  freq
# MSZoning       1460      5       RL  1151
# Street         1460      2     Pave  1454
# Alley            91      2     Grvl    50
# LotShape       1460      4      Reg   925
# LandContour    1460      4      Lvl  1311
# Utilities      1460      2   AllPub  1459
# LotConfig      1460      5   Inside  1052
# LandSlope      1460      3      Gtl  1382
# Neighborhood   1460     25    NAmes   225
# Condition1     1460      9     Norm  1260
# Condition2     1460      8     Norm  1445
# BldgType       1460      5     1Fam  1220
# HouseStyle     1460      8   1Story   726
# RoofStyle      1460      6    Gable  1141
# RoofMatl       1460      8  CompShg  1434
# Exterior1st    1460     15  VinylSd   515
# Exterior2nd    1460     16  VinylSd   504
# MasVnrType      588      3  BrkFace   445
# ExterQual      1460      4       TA   906
# ExterCond      1460      5       TA  1282
# Foundation     1460      6    PConc   647
# ...

# %% [markdown]
# The statistics of the Object Type columns indicate that most of them have null values. The columns also have very few unique values ranging from 2-25 categories, with majority of the columns having 2-9 categories. This columns could potentially be numerically encoded for modelling purposes in future chapters

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %% [markdown]
# The Train dataset contains integer, float and object Type columns, with a majority being object types. Most of the columns have no null values, the columns that do, have a significant amount of missing values eg the `Alley` column. This will be explored further in upcoming cells. Some of the columns that should be time-oriented eg `YrSold` are labeled as object, this will be corrected in the upcoming chapter

# %%
train_df.isnull().sum().sort_values(ascending=False).loc[lambda s: s.ne(0)]
# Out:
# PoolQC          1453
# MiscFeature     1406
# Alley           1369
# Fence           1179
# MasVnrType       872
# FireplaceQu      690
# LotFrontage      259
# GarageYrBlt       81
# GarageCond        81
# GarageType        81
# GarageFinish      81
# GarageQual        81
# BsmtFinType2      38
# BsmtExposure      38
# BsmtQual          37
# BsmtCond          37
# BsmtFinType1      37
# MasVnrArea         8
# Electrical         1
# dtype: int64

# %%
nulls = train_df.isna().sum()[train_df.isna().sum()>0].sort_values()
ax = nulls.plot(kind='bar', figsize=(18,10), title='Distribution of Null Values per Column', xlabel='Columns with Null Values', ylabel='Number of Null Values' )

# Adding labels on bars
for i, v in enumerate(nulls):
    ax.text(i, v, str(v), ha='center', va='bottom')

plt.show()

# %% [markdown]
# The amount of null values in these columns will pose a significant problem when it comes to modelling. 16/19 of the columns are of object Type while 3 are numeric type. Further investigations of these columns is warranted. According to the data description file, 'nan' are part of the ctegories in these object type column. The following cells will demontrate this......................................................................

# %% [markdown]
# Below is an excerpt from the Data Secription column focusing on only the columns that have been listed as containing null values as above:
#
# * LotFrontage: Linear feet of street connected to property
#
# * Alley: Type of alley access to property
#
#        Grvl	Gravel
#        Pave	Paved
#        NA 	No alley access
#
# * MasVnrType: Masonry veneer type
#
#        BrkCmn	Brick Common
#        BrkFace	Brick Face
#        CBlock	Cinder Block
#        None	None
#        Stone	Stone
#
# * MasVnrArea: Masonry veneer area in square feet
#
#
# * BsmtQual: Evaluates the height of the basement
#
#        Ex	Excellent (100+ inches)
#        Gd	Good (90-99 inches)
#        TA	Typical (80-89 inches)
#        Fa	Fair (70-79 inches)
#        Po	Poor (<70 inches
#        NA	No Basement
#
# * BsmtCond: Evaluates the general condition of the basement
#
#        Ex	Excellent
#        Gd	Good
#        TA	Typical - slight dampness allowed
#        Fa	Fair - dampness or some cracking or settling
#        Po	Poor - Severe cracking, settling, or wetness
#        NA	No Basement
#
# * BsmtExposure: Refers to walkout or garden level walls
#
#        Gd	Good Exposure
#        Av	Average Exposure (split levels or foyers typically score average or above)
#        Mn	Mimimum Exposure
#        No	No Exposure
#        NA	No Basement
#
# * BsmtFinType1: Rating of basement finished area
#
#        GLQ	Good Living Quarters
#        ALQ	Average Living Quarters
#        BLQ	Below Average Living Quarters
#        Rec	Average Rec Room
#        LwQ	Low Quality
#        Unf	Unfinshed
#        NA	No Basement
#
# * BsmtFinType2: Rating of basement finished area (if multiple types)
#
#        GLQ	Good Living Quarters
#        ALQ	Average Living Quarters
#        BLQ	Below Average Living Quarters
#        Rec	Average Rec Room
#        LwQ	Low Quality
#        Unf	Unfinshed
#        NA	No Basement
#
# * FireplaceQu: Fireplace quality
#
#        Ex	Excellent - Exceptional Masonry Fireplace
#        Gd	Good - Masonry Fireplace in main level
#        TA	Average - Prefabricated Fireplace in main living area or Masonry Fireplace in basement
#        Fa	Fair - Prefabricated Fireplace in basement
#        Po	Poor - Ben Franklin Stove
#        NA	No Fireplace
#
# * GarageType: Garage location
#
#        2Types	More than one type of garage
#        Attchd	Attached to home
#        Basment	Basement Garage
#        BuiltIn	Built-In (Garage part of house - typically has room above garage)
#        CarPort	Car Port
#        Detchd	Detached from home
#        NA	No Garage
#
# * GarageYrBlt: Year garage was built
#
# * GarageFinish: Interior finish of the garage
#
#        Fin	Finished
#        RFn	Rough Finished
#        Unf	Unfinished
#        NA	No Garage
#
# * GarageQual: Garage quality
#
#        Ex	Excellent
#        Gd	Good
#        TA	Typical/Average
#        Fa	Fair
#        Po	Poor
#        NA	No Garage
#
# * GarageCond: Garage condition
#
#        Ex	Excellent
#        Gd	Good
#        TA	Typical/Average
#        Fa	Fair
#        Po	Poor
#        NA	No Garage
#
# * PoolQC: Pool quality
#
#        Ex	Excellent
#        Gd	Good
#        TA	Average/Typical
#        Fa	Fair
#        NA	No Pool
#
# * Fence: Fence quality
#
#        GdPrv	Good Privacy
#        MnPrv	Minimum Privacy
#        GdWo	Good Wood
#        MnWw	Minimum Wood/Wire
#        NA	No Fence
#
# * MiscFeature: Miscellaneous feature not covered in other categories
#
#        Elev	Elevator
#        Gar2	2nd Garage (if not described in garage section)
#        Othr	Other
#        Shed	Shed (over 100 SF)
#        TenC	Tennis Court
#        NA	None
# * Electrical: Electrical system
#
#        SBrkr	Standard Circuit Breakers & Romex
#        FuseA	Fuse Box over 60 AMP and all Romex wiring (Average)
#        FuseF	60 AMP Fuse Box and mostly Romex wiring (Fair)
#        FuseP	60 AMP Fuse Box and mostly knob & tube wiring (poor)
#        Mix	Mixed
# For the categorical features, apart from `Electrical`, it is quite clear that the `NA` label is part of the category and not necessarily absence of value. This is further explored in the upcoming cells

# %%
na_cols = train_df.isnull().sum().sort_values(ascending=False).loc[lambda s: s.ne(0)]
na_cols_list = na_cols.index.tolist()
na_num_cols_list = ['LotFrontage', 'GarageYrBlt', 'MasVnrArea']
na_obj_cols_list = [ele for ele in na_cols_list if ele not in na_num_cols_list]

# %%
print(na_num_cols_list)
# Out:
# ['LotFrontage', 'GarageYrBlt', 'MasVnrArea']

# %%
print(na_obj_cols_list)
# Out:
# ['PoolQC', 'MiscFeature', 'Alley', 'Fence', 'MasVnrType', 'FireplaceQu', 'GarageCond', 'GarageType', 'GarageFinish', 'GarageQual', 'BsmtFinType2', 'BsmtExposure', 'BsmtQual', 'BsmtCond', 'BsmtFinType1', 'Electrical']

# %%
for col in na_obj_cols_list:
    unique_values = train_df[col].value_counts(dropna=False)
    null_count = train_df[col].isnull().sum()
    print("Unique Categories and their Frequencies:")
    print(unique_values)
    print(f"Null Values Frequency: {null_count}")
    print("="*50)
# Out:
# Unique Categories and their Frequencies:
# PoolQC
# NaN    1453
# Gd        3
# Ex        2
# Fa        2
# Name: count, dtype: int64
# Null Values Frequency: 1453
# ...
# Unique Categories and their Frequencies:
# MiscFeature
# NaN     1406
# Shed      49
# Gar2       2
# Othr       2
# TenC       1
# Name: count, dtype: int64
# Null Values Frequency: 1406
# ...
# Unique Categories and their Frequencies:
# Alley
# NaN     1369
# Grvl      50
# Pave      41
# Name: count, dtype: int64
# Null Values Frequency: 1369
# ...
# Unique Categories and their Frequencies:
# Fence
# NaN      1179
# MnPrv     157
# GdPrv      59
# GdWo       54
# MnWw       11
# Name: count, dtype: int64
# Null Values Frequency: 1179
# ...
# Unique Categories and their Frequencies:
# MasVnrType
# NaN        872
# BrkFace    445
# Stone      128
# BrkCmn      15
# Name: count, dtype: int64
# Null Values Frequency: 872
# ...
# Unique Categories and their Frequencies:
# FireplaceQu
# NaN    690
# Gd     380
# TA     313
# Fa      33
# ...

# %% [markdown]
# These columns will be numerically encoded in the upcoming chapter.

# %%
response_hist = sns.histplot(train_df.SalePrice, kde=True)
response_hist
# Out:
# <Axes: xlabel='SalePrice', ylabel='Count'>

# %% [markdown]
# The response variable, `SalePrice` follows a normal distribution, The variable is skewed to the right
